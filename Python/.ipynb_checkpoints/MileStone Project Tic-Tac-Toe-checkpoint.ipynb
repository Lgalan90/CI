# %% [markdown]
# #Create board
# #choice int in an input -- user
# #choice = int, int will be added to the gameBoard's board[] accordingly
# #input = x or y turn base --computer
# #input will populate choice on the board
#     #ex. input = 4 for player x then add x to the board in position 4
# #turn ends for player x, player y is next
# #if position is already populated, return error message "this spot has already been taken"
#
# Step 2
# #if player x or player y have 3 consecutive = true, that player wins
# #else if no more moves are left end game and ask if they'd like to restart

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import random
import os
board = [
    ' ',
    ' ',
    ' ',
    ' ',
    ' ',
    ' ',
    ' ',
    ' ',
    ' ',
    ' '
    ]

# def gameRules():
#    print("""Enter the number corresponding to the location on the board:
#          0|1|2
#          -----
#          3|4|5
#          -----
#          6|7|8 """)
def gameBoard():
    print (board[1], '|', board[2], '|', board[3])
    print ('----------')
    print (board[4], '|', board[5], '|', board[6])
    print ('----------')
    print (board[7], '|', board[8], '|', board[9])
while True:
    gameBoard()
    computerChoice = random.randrange(1, 10)
    choice = int(input('Enter move: '))
    
    # enter player option to empty space
    if board[choice] == ' ' and board[choice] != 'x' and board[choice] != 'o':
        board[choice] = 'x'
        
        # enter computer random option to empty space
        if board[computerChoice] == ' ' and board[computerChoice] != 'x' and board[computerChoice] != 'o':
            board[computerChoice] = 'o'  
        
    else:
        gameBoard()
        print('Try a different space...')
        
    if (board[1] == "x" and board[2] == "x" and board[3] == "x") or \
        (board[4] == "x" and board[5] == "x" and board[6] == "x") or \
        (board[7] == "x" and board[8] == "x" and board[9] == "x") or \
        (board[1] == "x" and board[4] == "x" and board[7] == "x") or \
        (board[2] == "x" and board[5] == "x" and board[8] == "x") or \
        (board[3] == "x" and board[6] == "x" and board[9] == "x") or \
        (board[1] == "x" and board[5] == "x" and board[9] == "x") or \
        (board[3] == "x" and board[5] == "x" and board[7] == "x"):
        print("X Wins!")
    if (board[1] == "o" and board[2] == "o" and board[3] == "o") or \
        (board[4] == "o" and board[5] == "o" and board[6] == "o") or \
        (board[7] == "o" and board[8] == "o" and board[9] == "o") or \
        (board[1] == "o" and board[4] == "o" and board[7] == "o") or \
        (board[2] == "o" and board[5] == "o" and board[8] == "o") or \
        (board[3] == "o" and board[6] == "o" and board[9] == "o") or \
        (board[1] == "o" and board[5] == "o" and board[9] == "o") or \
        (board[3] == "o" and board[5] == "o" and board[7] == "o"):
        print("O Wins!")
# Out:
#   |   |
# ----------
#   |   |
# ----------
#   |   |
# Enter move: 1
# x |   |
# ----------
#   |   |
# ----------
#   | o |
# Enter move: 2
# x | x |
# ----------
# o |   |
# ----------
#   | o |
# Enter move: 2
# x | x |
# ----------
# o |   |
# ----------
#   | o |
# Try a different space...
# x | x |
# ----------
# o |   |
# ----------
#   | o |
# Enter move: 5
# x | x |
# ----------
# o | x |
# ----------
#   | o |
# Enter move: 5
# x | x |
# ----------
# o | x |
# ----------
#   | o |
# Try a different space...
# x | x |
# ----------
# o | x |
# ----------
#   | o |
# Enter move: 9
# X Wins!
# x | x |
# ----------
# o | x |
# ----------
#   | o | x

# %%
 
"""      
    #Computer Controls
    computerChoice = random.randrange(1, 10)
    choice = int(input('Enter move for X: '))

    # enter computer random option to empty space
    if board[computerChoice] != 'x' and board[computerChoice] != 'o' and board[computerChoice] == ' ':
        board[computerChoice] = 'o'
        gameBoard()
        
    else:
        gameBoard()
        print('Try a different space...')
    
    # win conditions for player o
    if (board[1] == "o" and board[2] == "o" and board[3] == "o") or \
        (board[4] == "o" and board[5] == "o" and board[6] == "o") or \
        (board[7] == "o" and board[8] == "o" and board[9] == "o") or \
        (board[1] == "o" and board[4] == "o" and board[7] == "o") or \
        (board[2] == "o" and board[5] == "o" and board[8] == "o") or \
        (board[3] == "o" and board[6] == "o" and board[9] == "o") or \
        (board[1] == "o" and board[5] == "o" and board[9] == "o") or \
        (board[3] == "o" and board[5] == "o" and board[7] == "o"):
        print("O Wins!")    
"""        
        
"""  
    # comment computer options for 2 player game
    choice = int(input('Enter move for O: '))

    # enter player option to empty space

    if board[choice] != 'x' and board[choice] != 'o' and board[choice] == ' ':
        board[choice] = 'o'
        gameBoard()
  
    else:
        gameBoard()
        print('Try a different space...')
        
    
    win conditions for player o
    if (board[1] == "o" and board[2] == "o" and board[3] == "o") or \
        (board[4] == "o" and board[5] == "o" and board[6] == "o") or \
        (board[7] == "o" and board[8] == "o" and board[9] == "o") or \
        (board[1] == "o" and board[4] == "o" and board[7] == "o") or \
        (board[2] == "o" and board[5] == "o" and board[8] == "o") or \
        (board[3] == "o" and board[6] == "o" and board[9] == "o") or \
        (board[1] == "o" and board[5] == "o" and board[9] == "o") or \
        (board[3] == "o" and board[5] == "o" and board[7] == "o"):
        print("O Wins!")
"""
